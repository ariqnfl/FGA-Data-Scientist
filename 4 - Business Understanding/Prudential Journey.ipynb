# %%
import pandas as pd

# %%
# Load dataset
dataset = pd.read_csv("dataset/train.csv")

# %% [markdown]
# ### Melihat 5 data pertama

# %%
dataset.head()
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   2               1             D3              10        0.076923
# 1   5               1             A1              26        0.076923
# 2   6               1             E1              26        0.076923
# 3   7               1             D4              10        0.487179
# 4   8               1             D2              26        0.230769
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0               2               1               1  0.641791  0.581818
# 1               2               3               1  0.059701  0.600000
# 2               2               3               1  0.029851  0.745455
# 3               2               3               1  0.164179  0.672727
# 4               2               3               1  0.417910  0.654545
#
#      ...     Medical_Keyword_40  Medical_Keyword_41  Medical_Keyword_42  \
# ...

# %%
dataset.shape[0]
# Out:
# 59381

# %% [markdown]
# ### Melihat shape dari dataset

# %%
dataset.shape
# Out:
# (59381, 128)

# %% [markdown]
# ### Melihat info dari dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Columns: 128 entries, Id to Response
# dtypes: float64(18), int64(109), object(1)
# memory usage: 58.0+ MB

# %%
#check null data
dataset.isnull().sum()[dataset.isnull().sum() != 0]
# Out:
# Employment_Info_1         19
# Employment_Info_4       6779
# Employment_Info_6      10854
# Insurance_History_5    25396
# Family_Hist_2          28656
# Family_Hist_3          34241
# Family_Hist_4          19184
# Family_Hist_5          41811
# Medical_History_1       8889
# Medical_History_10     58824
# Medical_History_15     44596
# Medical_History_24     55580
# Medical_History_32     58274
# dtype: int64

# %% [markdown]
# ### Statistik deskriptif dari dataset

# %%
dataset.describe()
# Out:
#                  Id  Product_Info_1  Product_Info_3  Product_Info_4  \
# count  59381.000000    59381.000000    59381.000000    59381.000000
# mean   39507.211515        1.026355       24.415655        0.328952
# std    22815.883089        0.160191        5.072885        0.282562
# min        2.000000        1.000000        1.000000        0.000000
# 25%    19780.000000        1.000000       26.000000        0.076923
# 50%    39487.000000        1.000000       26.000000        0.230769
# 75%    59211.000000        1.000000       26.000000        0.487179
# max    79146.000000        2.000000       38.000000        1.000000
#
#        Product_Info_5  Product_Info_6  Product_Info_7       Ins_Age  \
# count    59381.000000    59381.000000    59381.000000  59381.000000
# mean         2.006955        2.673599        1.043583      0.405567
# std          0.083107        0.739103        0.291949      0.197190
# min          2.000000        1.000000        1.000000      0.000000
# ...

# %%
dataset_corr = dataset.corr()

# %%
print(dataset_corr.loc['Ins_Age','BMI'])
# Out:
# 0.1370757035449161

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# melihat sebaran dari respon yang ada
sns.countplot(x='Response',data=dataset,palette="husl", order = range(1,9))

# %%
# melihat sebaran dari produk info yang ada
sns.countplot(x='Product_Info_2', data=dataset, 
              order=['A1','A2','A3','A4','A5','A6','A7','A8',
                     'B1','B2',
                     'C1','C2','C3','C4',
                     'D1','D2','D3','D4',
                     'E1'])

# %% [markdown]
# melakukan groupby dengan product_info 2 dan melihat datanya

# %%
dataset_groupby = dataset.groupby('Product_Info_2').mean().fillna(0)

# %%
dataset_groupby.head(10)
# Out:
#                           Id  Product_Info_1  Product_Info_3  Product_Info_4  \
# Product_Info_2
# A1              39563.844689        1.035971       24.998730        0.234476
# A2              40026.363728        1.012665       24.099797        0.175517
# A3              39599.356192        1.028659       24.476970        0.218562
# A4              37239.090476        1.028571       25.195238        0.270841
# A5              39001.361290        1.014194       24.436129        0.320921
# A6              39579.551478        1.020972       24.223070        0.404602
# A7              39929.831526        1.010123       23.803326        0.017688
# A8              39536.255743        1.016679       24.038040        0.178572
# B1              41021.611111        1.000000       25.870370        0.373409
# B2              39534.247772        1.038324       24.308378        0.412691
#
#                 Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age  \
# Product_Info_2
# ...

# %%
dataset_byResponse = dataset.groupby('Response').mean().fillna(0)

# %%
dataset_byResponse.head(10)
# Out:
#                     Id  Product_Info_1  Product_Info_3  Product_Info_4  \
# Response
# 1         39099.168036        1.019494       24.773804        0.253302
# 2         39639.976038        1.021062       24.801435        0.249476
# 3         40385.529121        1.021718       24.903258        0.214227
# 4         39387.725490        1.035014       24.728992        0.256563
# 5         39378.835052        1.022275       24.505891        0.247066
# 6         39932.584706        1.028487       24.967685        0.339379
# 7         39475.086957        1.045721       24.545908        0.349039
# 8         39359.473344        1.021858       23.726615        0.399572
#
#           Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# Response
# 1               2.006444        2.703560        1.048010  0.492908  0.713661
# 2               2.004731        2.685897        1.050977  0.460992  0.716220
# ...

# %%
dataset_unique = dataset.groupby('Response').nunique()
dataset_unique.head()
# Out:
#             Id  Product_Info_1  Product_Info_2  Product_Info_3  \
# Response
# 1         6207               2              19              21
# 2         6552               2              15              18
# 3         1013               2              19              17
# 4         1428               2              19              13
# 5         5432               2              19              17
#
#           Product_Info_4  Product_Info_5  Product_Info_6  Product_Info_7  \
# Response
# 1                    242               2               2               2
# 2                    230               2               2               2
# 3                     65               2               2               2
# 4                     73               2               2               2
# 5                    187               2               2               2
#
#           Ins_Age  Ht    ...     Medical_Keyword_40  Medical_Keyword_41  \
# Response                 ...
# ...

# %%
# multiple aggregation
multiagg = dataset.groupby('Response').agg(['mean','median'])
multiagg.head()
# Out:
#                     Id          Product_Info_1        Product_Info_3         \
#                   mean   median           mean median           mean median
# Response
# 1         39099.168036  39184.0       1.019494      1      24.773804     26
# 2         39639.976038  39872.0       1.021062      1      24.801435     26
# 3         40385.529121  40444.0       1.021718      1      24.903258     26
# 4         39387.725490  39748.0       1.035014      1      24.728992     26
# 5         39378.835052  39406.5       1.022275      1      24.505891     26
#
#          Product_Info_4           Product_Info_5         ...    \
#                    mean    median           mean median  ...
# Response                                                 ...
# 1              0.253302  0.184615       2.006444      2  ...
# 2              0.249476  0.230769       2.004731      2  ...
# 3              0.214227  0.117949       2.003949      2  ...
# ...

# %%
dataset.dtypes
# Out:
# Id                       int64
# Product_Info_1           int64
# Product_Info_2          object
# Product_Info_3           int64
# Product_Info_4         float64
# Product_Info_5           int64
# Product_Info_6           int64
# Product_Info_7           int64
# Ins_Age                float64
# Ht                     float64
# Wt                     float64
# BMI                    float64
# Employment_Info_1      float64
# Employment_Info_2        int64
# Employment_Info_3        int64
# Employment_Info_4      float64
# Employment_Info_5        int64
# Employment_Info_6      float64
# InsuredInfo_1            int64
# InsuredInfo_2            int64
# InsuredInfo_3            int64
# InsuredInfo_4            int64
# InsuredInfo_5            int64
# InsuredInfo_6            int64
# InsuredInfo_7            int64
# Insurance_History_1      int64
# Insurance_History_2      int64
# Insurance_History_3      int64
# Insurance_History_4      int64
# Insurance_History_5    float64
# ...

# %%
dataset.fillna(dataset.median(),inplace=True)

# %%
dataset.isnull().sum()[dataset.isnull().sum() != 0]
# Out:
# Series([], dtype: int64)

# %%
dataset.dtypes
# Out:
# Id                       int64
# Product_Info_1           int64
# Product_Info_2          object
# Product_Info_3           int64
# Product_Info_4         float64
# Product_Info_5           int64
# Product_Info_6           int64
# Product_Info_7           int64
# Ins_Age                float64
# Ht                     float64
# Wt                     float64
# BMI                    float64
# Employment_Info_1      float64
# Employment_Info_2        int64
# Employment_Info_3        int64
# Employment_Info_4      float64
# Employment_Info_5        int64
# Employment_Info_6      float64
# InsuredInfo_1            int64
# InsuredInfo_2            int64
# InsuredInfo_3            int64
# InsuredInfo_4            int64
# InsuredInfo_5            int64
# InsuredInfo_6            int64
# InsuredInfo_7            int64
# Insurance_History_1      int64
# Insurance_History_2      int64
# Insurance_History_3      int64
# Insurance_History_4      int64
# Insurance_History_5    float64
# ...
